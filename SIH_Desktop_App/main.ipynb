# %%
# !pip install flask pandas playwright textblob pytesseract pillow reportlab
# !pip install playwright
# Out:
# Requirement already satisfied: flask in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (2.3.1)
# Requirement already satisfied: pandas in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (2.2.2)
# Requirement already satisfied: playwright in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (1.46.0)
# Requirement already satisfied: textblob in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: pytesseract in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (0.3.10)
# Requirement already satisfied: pillow in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (10.3.0)
# Requirement already satisfied: reportlab in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (4.2.2)
# Requirement already satisfied: Werkzeug>=2.3.0 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from flask) (2.3.2)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from flask) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from flask) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from flask) (8.1.3)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from flask) (1.6.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: greenlet==3.0.3 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from playwright) (3.0.3)
# Requirement already satisfied: pyee==11.1.0 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from playwright) (11.1.0)
# Requirement already satisfied: typing-extensions in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from pyee==11.1.0->playwright) (4.10.0)
# Requirement already satisfied: nltk>=3.8 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from pytesseract) (23.1)
# Requirement already satisfied: chardet in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from reportlab) (5.2.0)
# Requirement already satisfied: colorama in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=3.1.2->flask) (2.1.2)
# Requirement already satisfied: joblib in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (4.66.4)
# Requirement already satisfied: six>=1.5 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: playwright in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (1.46.0)
# Requirement already satisfied: greenlet==3.0.3 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from playwright) (3.0.3)
# Requirement already satisfied: pyee==11.1.0 in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from playwright) (11.1.0)
# Requirement already satisfied: typing-extensions in c:\users\ksham\appdata\local\programs\python\python310\lib\site-packages (from pyee==11.1.0->playwright) (4.10.0)
# WARNING: There was an error checking the latest version of pip.

# %%
# !pip install validators
# Out:
# Collecting validators
#   Downloading validators-0.34.0-py3-none-any.whl.metadata (3.8 kB)
# Downloading validators-0.34.0-py3-none-any.whl (43 kB)
#    ---------------------------------------- 0.0/43.5 kB ? eta -:--:--
#    ---------------------------------------- 43.5/43.5 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: validators
# Successfully installed validators-0.34.0
# WARNING: There was an error checking the latest version of pip.

# %%
from flask import Flask, render_template, request, send_file, redirect, url_for, flash
import os
import pandas as pd
from playwright.sync_api import sync_playwright
from textblob import TextBlob
from PIL import Image, ImageEnhance, ImageOps
import pytesseract
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
import secrets
import validators

app = Flask(__name__)

# Initialize a secure random secret key for session management
app.secret_key = secrets.token_hex(16)

# Set directories for storing screenshots and comments
instagram_screenshot_dir = "static/images"
tweet_screenshot_dir = os.path.join("static", "tweet_screenshots")
tweet_text_dir = os.path.join("static", "tweet_texts")

# Ensure directories exist
os.makedirs(instagram_screenshot_dir, exist_ok=True)
os.makedirs(tweet_screenshot_dir, exist_ok=True)
os.makedirs(tweet_text_dir, exist_ok=True)

@app.route('/')
def index():
    return render_template('index.html')

@app.route('/process_instagram', methods=['POST'])
def process_instagram():
    instagram_url = request.form.get('instagram_url')

    if not instagram_url or not validators.url(instagram_url):
        flash("Please provide a valid Instagram post URL.")
        return redirect(url_for('index'))

    try:
        extracted_text, sentiment, screenshot_path = take_screenshot_and_extract_text(instagram_url)
        filename = os.path.basename(screenshot_path)
        return render_template('result.html', image_path=filename, text=extracted_text, sentiment=sentiment)
    except Exception as e:
        flash(f"Error processing the Instagram post: {e}")
        return redirect(url_for('index'))

@app.route('/process_tweet', methods=['POST'])
def process_tweet():
    profile_url = request.form.get('profile_url')

    if not profile_url or not validators.url(profile_url):
        flash("Please provide a valid X.com profile URL.")
        return redirect(url_for('index'))

    try:
        profile_data = scrape_profile(profile_url)
        tweet_id = profile_data.get("id", "unknown")
        return render_template('result.html', 
                               image_path=os.path.basename(profile_data['screenshot']),
                               text_path=os.path.basename(profile_data['text_file']),
                               text=profile_data['text'])
    except Exception as e:
        flash(f"Error processing the X.com profile: {e}")
        return redirect(url_for('index'))

def take_screenshot_and_extract_text(url: str):
    with sync_playwright() as pw:
        browser = pw.chromium.launch(headless=True)
        context = browser.new_context(viewport={"width": 1920, "height": 1080})
        page = context.new_page()

        page.goto(url)

        try:
            page.wait_for_selector("article", timeout=10000)
            post_id = url.split('/')[-2]
            page.wait_for_timeout(5000)
            screenshot_path = os.path.join(instagram_screenshot_dir, f"post_{post_id}.png")
            page.screenshot(path=screenshot_path)
            extracted_text = extract_text_from_image(screenshot_path)

            if extracted_text:
                sentiment = analyze_text(extracted_text)
                return extracted_text, sentiment, screenshot_path
            else:
                raise Exception("No text found in the screenshot!")

        except Exception as e:
            raise e
        finally:
            browser.close()

def scrape_profile(url: str) -> dict:
    with sync_playwright() as pw:
        browser = pw.chromium.launch(headless=True)
        context = browser.new_context(viewport={"width": 1920, "height": 1080})
        page = context.new_page()

        page.goto(url)
        page.wait_for_selector("[data-testid='primaryColumn']", timeout=10000)
        page.wait_for_timeout(3000)

        tweet_element = page.query_selector(f'[data-testid="tweet"]')
        tweet_id = url.split('/')[-1]

        if tweet_element:
            tweet_text = tweet_element.text_content()
            screenshot_path = os.path.join(tweet_screenshot_dir, f"tweet_{tweet_id}.png")
            tweet_element.screenshot(path=screenshot_path)
            text_file_path = os.path.join(tweet_text_dir, f"tweet_{tweet_id}.txt")
            with open(text_file_path, "w", encoding="utf-8") as text_file:
                text_file.write(tweet_text.strip())
            return {
                "id": tweet_id,
                "text": tweet_text.strip(),
                "screenshot": screenshot_path,
                "text_file": text_file_path
            }
        else:
            screenshot_path = os.path.join(tweet_screenshot_dir, f"page_{tweet_id}.png")
            page.screenshot(path=screenshot_path)
            page_text = page.text_content()
            page_text = page_text.strip() if page_text else ""
            text_file_path = os.path.join(tweet_text_dir, f"page_{tweet_id}.txt")
            with open(text_file_path, "w", encoding="utf-8") as text_file:
                text_file.write(page_text)
            return {
                "id": tweet_id,
                "text": page_text,
                "screenshot": screenshot_path,
                "text_file": text_file_path
            }

def extract_text_from_image(image_path: str) -> str:
    try:
        img = Image.open(image_path)
        img = ImageOps.grayscale(img)
        enhancer = ImageEnhance.Contrast(img)
        img = enhancer.enhance(2)
        custom_config = r'--oem 3 --psm 6'
        text = pytesseract.image_to_string(img, config=custom_config)
        return text.strip()
    except Exception as e:
        flash(f"Error extracting text from image: {e}")
        return ""

def analyze_text(text: str) -> float:
    try:
        blob = TextBlob(text)
        return blob.sentiment.polarity
    except Exception as e:
        flash(f"Error analyzing text sentiment: {e}")
        return 0.0

@app.route('/download_image/<filename>')
def download_image(filename):
    file_path_instagram = os.path.join(instagram_screenshot_dir, filename)
    file_path_tweet = os.path.join(tweet_screenshot_dir, filename)

    if os.path.exists(file_path_instagram):
        return send_file(file_path_instagram, as_attachment=True, mimetype='image/png')
    elif os.path.exists(file_path_tweet):
        return send_file(file_path_tweet, as_attachment=True, mimetype='image/png')
    else:
        flash(f"File {filename} not found. Please make sure the file exists.")
        return redirect(url_for('index'))

@app.route('/download_text/<filename>')
def download_text(filename):
    file_path = os.path.join(tweet_text_dir, filename)
    if os.path.exists(file_path):
        return send_file(file_path, as_attachment=True)
    else:
        flash(f"File {filename} not found. Please make sure the file exists.")
        return redirect(url_for('index'))

@app.route('/download_excel')
def download_excel():
    text = request.args.get('text')
    if not text:
        flash("No text available for generating Excel.")
        return redirect(url_for('index'))

    excel_path = os.path.join(instagram_screenshot_dir, 'extracted_data.xlsx')
    df = pd.DataFrame({'Extracted Text': [text]})
    df.to_excel(excel_path, index=False)
    return send_file(excel_path, as_attachment=True)

@app.route('/download_pdf')
def download_pdf():
    text = request.args.get('text')
    if not text:
        flash("No text available for generating PDF.")
        return redirect(url_for('index'))

    try:
        pdf_path = os.path.join(instagram_screenshot_dir, 'extracted_data_reportlab.pdf')

        c = canvas.Canvas(pdf_path, pagesize=letter)
        c.setFont("Helvetica", 12)
        text_object = c.beginText(40, 750)
        text_object.setFont("Helvetica", 12)
        text_object.textLines(text)
        c.drawText(text_object)
        c.showPage()
        c.save()

        return send_file(pdf_path, as_attachment=True)

    except Exception as e:
        flash(f"Error generating PDF: {e}")
        return redirect(url_for('index'))

if __name__ == "__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\ksham\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3534: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
